# %%
from __future__ import print_function
import os
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
 
import chainer
from __future__ import print_function
from tqdm import tqdm
import numpy as np
import chainer
import os
import re
import torch
import torch.nn.functional as F
from torch.utils.data import TensorDataset, DataLoader

# %%
train, val, test = chainer.datasets.get_ptb_words()

# %%
ptb_dict = chainer.datasets.get_ptb_words_vocabulary()
print('Number of vocabulary', len(ptb_dict))print('ptb_dict', ptb_dict)
# Out:
# Number of vocabulary 10000
# ...

# %%
def preprocess_ptb(train, ptb_dict):
    ptb_word_id_dict = ptb_dict
    ptb_id_word_dict = dict((v,k) for k,v in ptb_word_id_dict.items())
    return [ptb_id_word_dict[i] for i in train]

# %%
data = preprocess_ptb(train, ptb_dict)

# %%
eos = []
for i in range(len(data)):
    if data[i] == '<eos>'
